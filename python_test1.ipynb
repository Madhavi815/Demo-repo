# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhavi815/Demo-repo/blob/main/python_test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [1, 2, 3, 4, 5, True]
l.pop(True)
print(l)
# Out:
# [1, 3, 4, 5, True]
